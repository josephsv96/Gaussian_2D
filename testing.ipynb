# %%
import numpy as np
import matplotlib.pyplot as plt
import pathlib

# %%
from gaussian_classifier import SegmentaionMap
from img_bmp_utils import read_npy

# %%
# DATASET_DIR = pathlib.Path(input("Enter image dir:"))
DATASET_DIR = pathlib.Path(pathlib.Path.cwd() / 'data/ground_truth_sim/dataset')

# Loading image, annotation array
img_arr, ann_arr = read_npy(DATASET_DIR)

# Sample
plt.imshow(ann_arr[0])
# Out:
# Image array: (4, 128, 128, 3)
# Annotation array: (4, 128, 128)

# %%
gaussians_ann = SegmentaionMap(ann_arr)

# %%
gaussian_cat = gaussians_ann.arr_to_categorical()

# %%
gaussian_cat.shape
# Out:
# (4, 128, 128, 7)

# %%
plt.imshow(gaussian_cat[1,:,:,6])

# %%
sample = gaussian_cat[0,:,:,3]

# %%
num = gaussians_ann.get_density()
print(np.around(num[:,1:], 3)  *100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8d170788a3ea> in <module>
#       1 num = gaussians_ann.get_density()
# ----> 2 print(around(num[:,1:], 3)  *100)
#
# NameError: name 'around' is not defined

# %%
num.shape
# Out:
# (4, 7)

# %%
gaussians_ann.imshow_prediciton()
# Out:
# [ 4.41894531  1.58081055  4.52880859 12.6159668   8.73413086 21.74682617]
