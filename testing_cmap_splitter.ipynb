# %%
import numpy as np
import matplotlib.pyplot as plt
import pathlib

# %%
from img_bmp_utils import read_cmp_npy
from cmap_splitter import CmapSplitter

# %%
# DATASET_DIR = pathlib.Path(input("Enter image dir:"))
DATASET_DIR = pathlib.Path(pathlib.Path.cwd() / 'data/splitter_data/dataset')

# Loading image, annotation array
ann_arr = read_cmp_npy(DATASET_DIR)

# Sample
plt.imshow(ann_arr[0])
# Out:
# Annotation array: (30, 256, 256)

# %%
width = 128
height = 128
x_off = 5
y_off = 5

# %%
sample = ann_obj.split_to_4(width, height, x_off, y_off)[0,:]
plt.imshow(sample)
