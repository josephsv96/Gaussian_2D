# %%
import cv2
import matplotlib.pyplot as plt

from remove_barrel_disrotions import barrel_undist

# %%
src = cv2.imread("sample.bmp",cv2.COLOR_RGB2BGR)
dst = barrel_undist(src)

# %%
cv2.imwrite("sample_undist.bmp", dst)
# Out:
# True

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(src)
plt.subplot(1,2,2)
plt.imshow(dst)
